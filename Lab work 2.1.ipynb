# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.1

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними типами та структурами даних в Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# #### Завдання 1

# %% [markdown]
# Обчислити площу трикутника, коли відома сторона та проведена висота до неї

# %%
a = int(input("введите длину стороны треугольника"))
h = int(input("введите высоту стороны треугольника"))

s = 0.5*a*h
print("площадь равна", s)
# Out:
# введите длину стороны треугольника6
# введите высоту стороны треугольника8
# площадь равна 24.0

# %% [markdown]
# #### Завдання 2

# %% [markdown]
# Дано трицифрове число. Виведіть окремо кожну цифру числа та суми цифр число
#
# Реалізуйте завдання двома способами (використовуючи стрічки та оператори `%`, `//`)

# %%
N = input("введіть трицефрове число")
print(N[0])
print(N[1])
print(N[2])
print("cумма цифр числа", int(N[0])+int(N[1])+int(N[2]))
# Out:
# введіть трицефрове число345
# 3
# 4
# 5
# cумма цифр числа 12

# %%
N = int(input("введіть трицефрове число"))
print(N//100)
print((N%100)//10)
print(N%10)
print("cумма цифр числа",N//100+(N%100)//10+N%10)
# Out:
# введіть трицефрове число345
# 3
# 4
# 5
# cумма цифр числа 12

# %% [markdown]
# #### Завдання 3

# %% [markdown]
# Дано речення (стрічка).
# * Розбийте речення по словах і помістіть їх у список.
# * Виведіть кількість слів у речені.
# * Утворіть нове речення, що складається з першого та останнього слова із початкового речення.

# %%
sentence = 'My favourite tutor in academy is Ihor'

# %%
spisok = sentence.split()
spisok
# Out:
# ['My', 'favourite', 'tutor', 'in', 'academy', 'is', 'Ihor']

# %%
len(spisok)
# Out:
# 7

# %%
spisok[0]+" "+spisok[-1]
# Out:
# 'My Ihor'

# %% [markdown]
# #### Завдання 4

# %% [markdown]
# Перевірте, чи справджується формула: $$ sin^2x + cos^2x = 1$$
#
# Напишіть код, що реалізує цю формулу. Нагадую, що тригонометричні функції приймають аргументи в радіанній мірі

# %%
x = int(input())
import math 
print(math.sin(x)**2+math.cos(x)**2)
if round(math.sin(x)**2+math.cos(x)**2)==1:
    print("доказано")
# Out:
# 5
# 0.9999999999999999
# доказано

# %% [markdown]
# #### Завдання 5

# %% [markdown]
# ###### Напишіть програму для обчислення коренів квадратного рівняння.
#
# Нагадую, що `n`-го степеня має `n` коренів. (Корені можуть бути комплексні)

# %%
import cmath
a = int(input("ВВедіть а"))
b = int(input("ВВедіть b"))
c = int(input("Введіть с"))

D = b*b-4*a*c
x1 = (-b+(D)**(1/2))/(2*a) 
x2 = (-b-(D)**(1/2))/(2*a) 
print("корені рівняння: ", x1,x2)
# Out:
# ВВедіть а1
# ВВедіть b2
# Введіть с8
# корені рівняння:  (-0.9999999999999999+2.6457513110645907j) (-1.0000000000000002-2.6457513110645907j)

# %% [markdown]
# Завдання 6

# %% [markdown]
# Напишіть програму, що виводить речення: <i>"Діаметр планети `Planet` дорівнює` Diament`"</i>,
#
# де `Planet` та `Diament` вводить користувач

# %%
name = input("ВВедіть ім'я планети")
d = input("ВВедіть діаметр планети")

print(f"діметр планети {name} дорівнює {d}")
# Out:
# ВВедіть ім'я планетиMars
# ВВедіть діаметр планети5000
# діметр планети Mars дорівнює 5000
